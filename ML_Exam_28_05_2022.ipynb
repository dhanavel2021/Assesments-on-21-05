# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanavel2021/Machine-Learning-Test-21-05-2022/blob/main/ML_Exam_28_05_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/credit_card.csv")

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df=df.drop(["CUST_ID"],axis=1)

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %% [markdown]
# ***Q1. What does the primary analysis of several categorical
# features reveal?***

# %% [markdown]
# 1) The categorial features reveal about the credit card customer's purchases and their payments on their purchases.
#
# 2) It shows that how the credit card customers done their payments, wheather they're paying the cash in advance or they're paying the cash in installments.
#
# 3) And about their minimum and maximum payments and their credit card limits.
#
# 4) And wheather the customers are purchasing frequently, or purchasing in one go.

# %% [markdown]
# ***Q2. Perform the following Exploratory Data Analysis tasks:***

# %% [markdown]
# ***a. Missing Value Analysis***

# %%
df=df.dropna()
df.isna().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# ***b. Outlier Treatment using the Z-score method***

# %%
me = np.mean(df)
s = np.std(df)
print("Mean:",me)
print("Standard Deviation:",s)
# Out:
# Mean: BALANCE                             1601.224893
# BALANCE_FREQUENCY                      0.895035
# PURCHASES                           1025.433874
# ONEOFF_PURCHASES                     604.901438
# INSTALLMENTS_PURCHASES               420.843533
# CASH_ADVANCE                         994.175523
# PURCHASES_FREQUENCY                    0.496000
# ONEOFF_PURCHASES_FREQUENCY             0.205909
# PURCHASES_INSTALLMENTS_FREQUENCY       0.368820
# CASH_ADVANCE_FREQUENCY                 0.137604
# CASH_ADVANCE_TRX                       3.313918
# PURCHASES_TRX                         15.033233
# CREDIT_LIMIT                        4522.091030
# PAYMENTS                            1784.478099
# MINIMUM_PAYMENTS                     864.304943
# PRC_FULL_PAYMENT                       0.159304
# TENURE                                11.534391
# dtype: float64
# Standard Deviation: BALANCE                             2095.449969
# BALANCE_FREQUENCY                      0.207685
# ...

# %%
q1 = df.quantile(0.25)
q2 = df.quantile(0.75)
iqr = q2 - q1
outliers = df[((df<(q1-1.5*iqr)) | (df>(q2+1.5*iqr)))]

# %%
print("Outliers:" + str(len(out)))
# Out:
# Outliers:8636

# %%
print("Min:" + str(out.min()))
# Out:
# Min:BALANCE                              5044.179003
# BALANCE_FREQUENCY                       0.000000
# PURCHASES                            2800.120000
# ONEOFF_PURCHASES                     1499.120000
# INSTALLMENTS_PURCHASES               1211.420000
# CASH_ADVANCE                         2831.836214
# PURCHASES_FREQUENCY                          NaN
# ONEOFF_PURCHASES_FREQUENCY              0.833333
# PURCHASES_INSTALLMENTS_FREQUENCY             NaN
# CASH_ADVANCE_FREQUENCY                  0.636364
# CASH_ADVANCE_TRX                       11.000000
# PURCHASES_TRX                          44.000000
# CREDIT_LIMIT                        14000.000000
# PAYMENTS                             4256.385553
# MINIMUM_PAYMENTS                     1815.957627
# PRC_FULL_PAYMENT                        0.428571
# TENURE                                  6.000000
# dtype: float64

# %%
print("Max:" + str(out.max()))
# Out:
# Max:BALANCE                             19043.13856
# BALANCE_FREQUENCY                       0.75000
# PURCHASES                           49039.57000
# ONEOFF_PURCHASES                    40761.25000
# INSTALLMENTS_PURCHASES              22500.00000
# CASH_ADVANCE                        47137.21176
# PURCHASES_FREQUENCY                         NaN
# ONEOFF_PURCHASES_FREQUENCY              1.00000
# PURCHASES_INSTALLMENTS_FREQUENCY            NaN
# CASH_ADVANCE_FREQUENCY                  1.50000
# CASH_ADVANCE_TRX                      123.00000
# PURCHASES_TRX                         358.00000
# CREDIT_LIMIT                        30000.00000
# PAYMENTS                            50721.48336
# MINIMUM_PAYMENTS                    76406.20752
# PRC_FULL_PAYMENT                        1.00000
# TENURE                                 11.00000
# dtype: float64

# %%
from scipy import stats
z_score = stats.zscore(out)
z_score_a = np.abs(z_score)
g = (z_score_a < 3).all(axis=1)
print(g)
# Out:
# [False False False ... False False False]

# %% [markdown]
# ***c. Deal with correlated variables***

# %%
df.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.310140   0.176083
# BALANCE_FREQUENCY                 0.310140           1.000000   0.122635
# PURCHASES                         0.176083           0.122635   1.000000
# ONEOFF_PURCHASES                  0.159985           0.095254   0.916780
# INSTALLMENTS_PURCHASES            0.122109           0.114739   0.679259
# CASH_ADVANCE                      0.495586           0.089036  -0.053760
# PURCHASES_FREQUENCY              -0.088459           0.228158   0.393000
# ONEOFF_PURCHASES_FREQUENCY        0.063832           0.187467   0.497384
# PURCHASES_INSTALLMENTS_FREQUENCY -0.069582           0.184159   0.316025
# CASH_ADVANCE_FREQUENCY            0.445307           0.181132  -0.124863
# CASH_ADVANCE_TRX                  0.382388           0.133265  -0.070277
# PURCHASES_TRX                     0.147887           0.183095   0.688732
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8636.000000        8636.000000   8636.000000       8636.000000
# mean    1601.224893           0.895035   1025.433874        604.901438
# std     2095.571300           0.207697   2167.107984       1684.307803
# min        0.000000           0.000000      0.000000          0.000000
# 25%      148.095189           0.909091     43.367500          0.000000
# 50%      916.855459           1.000000    375.405000         44.995000
# 75%     2105.195853           1.000000   1145.980000        599.100000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8636.000000   8636.000000          8636.000000
# mean               420.843533    994.175523             0.496000
# std                917.245182   2121.458303             0.401273
# min                  0.000000      0.000000             0.000000
# ...

# %% [markdown]
# ***Q3. Perform dimensionality reduction using PCA such that the
# 95% of the variance is explained***

# %%
x=df.drop(['TENURE'],axis=1)
y=df['TENURE']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.75,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

m=LogisticRegression()

# %%
m.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
p=m.predict(xtest)
p
# Out:
# array([12, 12, 12, ..., 12, 12, 12])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(ytest,p)
# Out:
# 0.8550254747568319

# %%
confusion_matrix(ytest,p)
# Out:
# array([[   6,    0,    0,    0,    0,    0,   38],
#        [   2,    0,    0,    0,    0,    0,   39],
#        [   3,    0,    0,    0,    0,    0,   38],
#        [   1,    0,    0,    0,    0,    0,   43],
#        [   0,    0,    0,    0,    0,    0,   49],
#        [   0,    0,    0,    0,    0,    0,   92],
#        [   2,    0,    2,    4,    0,    0, 1840]])

# %%
z=classification_report(ytest,p)
print(z)
# Out:
#               precision    recall  f1-score   support
#
#            6       0.43      0.14      0.21        44
#            7       0.00      0.00      0.00        41
#            8       0.00      0.00      0.00        41
#            9       0.00      0.00      0.00        44
#           10       0.00      0.00      0.00        49
#           11       0.00      0.00      0.00        92
#           12       0.86      1.00      0.92      1848
#
#     accuracy                           0.86      2159
#    macro avg       0.18      0.16      0.16      2159
# weighted avg       0.75      0.86      0.79      2159
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.decomposition import PCA
pc=PCA(n_components=0.95)

# %%
pc.fit(xtrain)
# Out:
# PCA(n_components=0.95)

# %%
xtrain_transformed=pc.transform(xtrain)
print(xtrain_transformed.shape)
# Out:
# (6477, 5)

# %%
xtest_transformed=pc.transform(xtest)
print(xtest_transformed.shape)
# Out:
# (2159, 5)

# %%
new=LogisticRegression(penalty='l1',solver='liblinear')

# %%
new.fit(xtrain_transformed,ytrain)
# Out:
# LogisticRegression(penalty='l1', solver='liblinear')

# %%
new_p=new.predict(xtest_transformed)

# %%
ytest,p,new_p
# Out:
# (613     12
#  5632    12
#  4983    12
#  7966    12
#  6427    12
#          ..
#  2825     7
#  4778    12
#  1209    10
#  4146    12
#  4771    12
#  Name: TENURE, Length: 2159, dtype: int64,
#  array([12, 12, 12, ..., 12, 12, 12]),
#  array([12, 12, 12, ..., 12, 12, 12]))

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(new_p,ytest)
acc
# Out:
# 0.8564150069476609

# %% [markdown]
# ***Q4. Find the optimum value of k for k-means clustering using
# the elbow method. Plot the elbow curve***

# %%
import sklearn
from sklearn.cluster import KMeans

# %%
w=[]

for i in range(1,7):
  km=KMeans(n_clusters=i, 
                init='k-means++', 
                n_init=10, 
                max_iter=300, 
                tol=0.0001,  
                verbose=0, 
                random_state=None, 
                copy_x=True,  
                algorithm='auto')
  
  km.fit(df)

  w.append(km.inertia_)

# %%
import matplotlib.pyplot as plt

plt.plot(range(1,7),w)

# %% [markdown]
# ***Q5. Find the optimum value of k for k-means clustering using
# the silhouette score method and specify the number of
# observations in each cluster using a bar plot***

# %%
import sklearn.metrics as metrics
for i in range(3,10):
    kme=KMeans(n_clusters=i,
                  init="k-means++",
                  random_state=200)
    kme.fit(df)
    labels=kme.labels_
    print ("Silhouette score= "+str(i)+" is "+str(metrics.silhouette_score(df,
                                         labels,
                                         metric="euclidean",
                                         sample_size=1000,
                                         random_state=200)))
# Out:
# Silhouette score= 3 is 0.44107332312800074
# Silhouette score= 4 is 0.44491892289667373
# Silhouette score= 5 is 0.3866741315370564
# Silhouette score= 6 is 0.4016724566597089
# Silhouette score= 7 is 0.35816969639589735
# Silhouette score= 8 is 0.3754316278591276
# Silhouette score= 9 is 0.346034043336338

# %%
import matplotlib.pyplot as plt
from yellowbrick.cluster import SilhouetteVisualizer

fig, ax = plt.subplots(2, 2, figsize=(10,15))
for i in [2, 3, 4, 5]:
    kms = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    e, mo = divmod(i, 2)
    v = SilhouetteVisualizer(kms, colors='Accent', ax=ax[e-1][mo])
    v.fit(x)

# %% [markdown]
# **PART 2**

# %% [markdown]
# ***Q1. Print the total number of positive and negative sentiments.***

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/Sentiment.csv")

# %%
s=data['sentiment']

# %%
d=np.array(s)

# %%
p=0
n=0
for i in range(0,len(d)):
  if d[i]=='Positive':
    p=p+1
  elif d[i]=='Negative':
    n=n+1
print("Number of Positives:", p)
print("Number of Negatives:", n)
# Out:
# Number of Positives: 2236
# Number of Negatives: 8493

# %% [markdown]
# ***Q2. Build a sequential LSTM model to predict positive and
# negative sentiments.***

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus = []
for i in range(0, 13871):
    review = re.sub('[^a-zA-Z]', ' ', 
                    data['text'][i])
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['rt nancyleegrahn everyon feel climat chang question last night exactli gopdeb',
#  'rt scottwalk catch full gopdeb last night scott best line second walker http co zsff',
#  'rt tjmshow mention tamir rice gopdeb held cleveland wow',
#  'rt robgeorg carli fiorina trend hour debat men complet gopdeb say',
#  'rt danscavino gopdeb w realdonaldtrump deliv highest rate histori presidenti debat trump http co',
#  'rt gregabbott tx tedcruz first day rescind everi illeg execut action taken barack obama gopdeb foxnew',
#  'rt warriorwoman like happi heard go moder anymor gopdeb megynkelli http',
#  'go msnbc live thomasarobert around pm et gopdeb',
#  'deer headlight rt lizzwinstead ben carson may brain surgeon perform lobotomi gopdeb',
#  'rt nancyosborn last night debat prove gopdeb batsask badassteachersa tbat http co g ggji bjd',
#  'jgreendc realdonaldtrump fair billclinton own phrase gopdeb',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features = 1500)

# %%
x = cv.fit_transform(corpus).toarray()


y = data['sentiment'].values

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(x, 
                                                    y, 
                                                    test_size = 0.30, 
                                                    random_state = 0)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(xtrain, ytrain)
# Out:
# GaussianNB()

# %%
yp = classifier.predict(xtest)

# %% [markdown]
# ***Q3.
# Based on the model, check the sentiment for the following
# two sentences
# a. 'He is a great leader.'
# b. 'He is a terrible leader.'***
